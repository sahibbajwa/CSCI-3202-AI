# %%
# Python3 program to create target string, starting from 
# random string using Genetic Algorithm 
# Author Atul Kumar on https://www.geeksforgeeks.org/genetic-algorithms/

import random 

# Number of individuals in each generation 
POPULATION_SIZE = 100

# Valid genes 
GENES = '''abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOP 
QRSTUVWXYZ 1234567890, .-;:_!"#%&/()=?@${[]}'''

# Target string to be generated 
TARGET = "To be or not to be."

class Individual(object): 
    ''' 
    Class representing individual in population 
    '''
    def __init__(self, chromosome): 
        self.chromosome = chromosome 
        self.fitness = self.cal_fitness() 

    @classmethod
    def mutated_genes(self): 
        ''' 
        create random genes for mutation 
        '''
        global GENES 
        gene = random.choice(GENES) 
        return gene 

    @classmethod
    def create_gnome(self): 
        ''' 
        create chromosome or string of genes 
        '''
        global TARGET 
        gnome_len = len(TARGET) 
        return [self.mutated_genes() for _ in range(gnome_len)] 

    def mate(self, par2): 
        ''' 
        Perform mating and produce new offspring 
        '''

        # chromosome for offspring 
        child_chromosome = [] 
        for gp1, gp2 in zip(self.chromosome, par2.chromosome):	 

            # random probability 
            prob = random.random() 

            # if prob is less than 0.45, insert gene 
            # from parent 1 
            if prob < 0.45: 
                child_chromosome.append(gp1) 

            # if prob is between 0.45 and 0.90, insert 
            # gene from parent 2 
            elif prob < 0.90: 
                child_chromosome.append(gp2) 

            # otherwise insert random gene(mutate), 
            # for maintaining diversity 
            else: 
                child_chromosome.append(self.mutated_genes()) 

        # create new Individual(offspring) using 
        # generated chromosome for offspring 
        return Individual(child_chromosome) 

    def cal_fitness(self): 
        ''' 
        Calculate fittness score, it is the number of 
        characters in string which differ from target 
        string. 
        '''
        global TARGET 
        fitness = 0
        for gs, gt in zip(self.chromosome, TARGET): 
            if gs != gt: fitness+= 1
        return fitness 

# Driver code 
def main(): 
    global POPULATION_SIZE 

    #current generation 
    generation = 1

    found = False
    population = [] 

    # create initial population 
    for _ in range(POPULATION_SIZE): 
                gnome = Individual.create_gnome() 
                population.append(Individual(gnome)) 

    while not found: 

        # sort the population in increasing order of fitness score 
        population = sorted(population, key = lambda x:x.fitness) 

        # if the individual having lowest fitness score ie. 
        # 0 then we know that we have reached to the target 
        # and break the loop 
        if population[0].fitness <= 0: 
            found = True
            break

        # Otherwise generate new offsprings for new generation 
        new_generation = [] 

        # Perform Elitism, that mean 10% of fittest population 
        # goes to the next generation 
        s = int((10*POPULATION_SIZE)/100) 
        new_generation.extend(population[:s]) 

        # From 50% of fittest population, Individuals 
        # will mate to produce offspring 
        s = int((90*POPULATION_SIZE)/100) 
        for _ in range(s): 
            parent1 = random.choice(population[:50]) 
            parent2 = random.choice(population[:50]) 
            child = parent1.mate(parent2) 
            new_generation.append(child) 

        population = new_generation 

        print("Generation: {}\tString: {}\tFitness: {}".format(generation,"".join(population[0].chromosome),population[0].fitness)) 

        generation += 1


    print("Generation: {}\tString: {}\tFitness: {}".format(generation,"".join(population[0].chromosome),population[0].fitness)) 

if __name__ == '__main__': 
    main()
# Out:
# Generation: 1	String: 43 k-z1r h/aaU 702i	Fitness: 16
# Generation: 2	String: 43 k-z1r h/aaU 702i	Fitness: 16
# Generation: 3	String: 43 k-z1r h/aaU 702i	Fitness: 16
# Generation: 4	String: ToYx- 1rBb$aanG7@2i	Fitness: 15
# Generation: 5	String: To[X- 1  n$0 n 7@=i	Fitness: 13
# Generation: 6	String: TH b- bp nsW # #bYk	Fitness: 11
# Generation: 7	String: TH b- bp nsW # #bYk	Fitness: 11
# Generation: 8	String: TH b- bp nsW # #bYk	Fitness: 11
# Generation: 9	String: TH b- bp nsW # #bYk	Fitness: 11
# Generation: 10	String: T  b  %r n6W po#b=E	Fitness: 9
# Generation: 11	String: T  b  %r n6W po#b=E	Fitness: 9
# Generation: 12	String: T  b  %r n6W po#b=E	Fitness: 9
# Generation: 13	String: T  b  %r n6W po#b=E	Fitness: 9
# Generation: 14	String: T  b  %r n6W po#b=E	Fitness: 9
# Generation: 15	String: To bA Qr not # nDD@	Fitness: 8
# Generation: 16	String: T  bh Xr not So&b!R	Fitness: 7
# Generation: 17	String: T  bh Xr not So&b!R	Fitness: 7
# Generation: 18	String: T  bh Xr not So&b!R	Fitness: 7
# Generation: 19	String: T  bh Xr not So&b!R	Fitness: 7
# Generation: 20	String: To b- er not$yo b=9	Fitness: 6
# Generation: 21	String: To bK er not Zo b==	Fitness: 5
# Generation: 22	String: To bK er not Zo b==	Fitness: 5
# Generation: 23	String: To bK er not Zo b==	Fitness: 5
# Generation: 24	String: To bK er not Zo b==	Fitness: 5
# Generation: 25	String: To bK er not Zo b==	Fitness: 5
# Generation: 26	String: To bK er not Zo b==	Fitness: 5
# Generation: 27	String: To bK er not Zo b==	Fitness: 5
# Generation: 28	String: To bK er not Zo b==	Fitness: 5
# Generation: 29	String: To bK er not Zo b==	Fitness: 5
# Generation: 30	String: To bK er not Zo b==	Fitness: 5
# Generation: 31	String: To bK er not Zo b==	Fitness: 5
# Generation: 32	String: To bK er not Zo b==	Fitness: 5
# Generation: 33	String: To bK er not Zo b==	Fitness: 5
# Generation: 34	String: To bK er not Zo b==	Fitness: 5
# Generation: 35	String: To bK er not Zo b==	Fitness: 5
# Generation: 36	String: To bK er not Zo b==	Fitness: 5
# Generation: 37	String: To bK er not Zo b==	Fitness: 5
# Generation: 38	String: To bK er not Zo b==	Fitness: 5
# Generation: 39	String: To bK er not Zo b==	Fitness: 5
# Generation: 40	String: To bK er not Zo b==	Fitness: 5
# Generation: 41	String: To bK er not Zo b==	Fitness: 5
# Generation: 42	String: To bK er not Zo b==	Fitness: 5
# Generation: 43	String: To b- Xr not to b
# 	Fitness: 4
# Generation: 44	String: To b- Xr not to b
# 	Fitness: 4
# Generation: 45	String: To b- Xr not to b
# 	Fitness: 4
# Generation: 46	String: To b- Xr not to b
# 	Fitness: 4
# Generation: 47	String: To b- Xr not to b
# 	Fitness: 4
# Generation: 48	String: To b- Xr not to b
# 	Fitness: 4
# Generation: 49	String: To b- Xr not to b
# 	Fitness: 4
# Generation: 50	String: To b- Xr not to b
# 	Fitness: 4
# Generation: 51	String: To b- Xr not to b
# 	Fitness: 4
# Generation: 52	String: To b- Xr not to b
# 	Fitness: 4
# Generation: 53	String: To b- -r not to bx.	Fitness: 3
# Generation: 54	String: To b- -r not to bx.	Fitness: 3
# Generation: 55	String: To b- -r not to bx.	Fitness: 3
# Generation: 56	String: To b- -r not to bx.	Fitness: 3
# Generation: 57	String: To b- -r not to bx.	Fitness: 3
# Generation: 58	String: To b- -r not to bx.	Fitness: 3
# Generation: 59	String: To b- -r not to bx.	Fitness: 3
# Generation: 60	String: To b- -r not to bx.	Fitness: 3
# Generation: 61	String: To be -r not to bx.	Fitness: 2
# Generation: 62	String: To be -r not to bx.	Fitness: 2
# Generation: 63	String: To be -r not to bx.	Fitness: 2
# Generation: 64	String: To be -r not to bx.	Fitness: 2
# Generation: 65	String: To be -r not to bx.	Fitness: 2
# Generation: 66	String: To be -r not to bx.	Fitness: 2
# Generation: 67	String: To be -r not to bx.	Fitness: 2
# Generation: 68	String: To be -r not to bx.	Fitness: 2
# Generation: 69	String: To be -r not to bx.	Fitness: 2
# Generation: 70	String: To be -r not to bx.	Fitness: 2
# Generation: 71	String: To be -r not to bx.	Fitness: 2
# Generation: 72	String: To be -r not to bx.	Fitness: 2
# Generation: 73	String: To be -r not to bx.	Fitness: 2
# Generation: 74	String: To be -r not to bx.	Fitness: 2
# Generation: 75	String: To be -r not to bx.	Fitness: 2
# Generation: 76	String: To be -r not to bx.	Fitness: 2
# Generation: 77	String: To be -r not to bx.	Fitness: 2
# Generation: 78	String: To be -r not to bx.	Fitness: 2
# Generation: 79	String: To be -r not to bx.	Fitness: 2
# Generation: 80	String: To be -r not to bx.	Fitness: 2
# Generation: 81	String: To be -r not to bx.	Fitness: 2
# Generation: 82	String: To be -r not to bx.	Fitness: 2
# Generation: 83	String: To be -r not to bx.	Fitness: 2
# Generation: 84	String: To be -r not to bx.	Fitness: 2
# Generation: 85	String: To be -r not to bx.	Fitness: 2
# Generation: 86	String: To be -r not to bx.	Fitness: 2
# Generation: 87	String: To be -r not to bx.	Fitness: 2
# Generation: 88	String: To be -r not to bx.	Fitness: 2
# Generation: 89	String: To be -r not to bx.	Fitness: 2
# Generation: 90	String: To be -r not to bx.	Fitness: 2
# Generation: 91	String: To be -r not to bx.	Fitness: 2
# Generation: 92	String: To be -r not to bx.	Fitness: 2
# Generation: 93	String: To be -r not to bx.	Fitness: 2
# Generation: 94	String: To be -r not to bx.	Fitness: 2
# Generation: 95	String: To be -r not to bx.	Fitness: 2
# Generation: 96	String: To be -r not to bx.	Fitness: 2
# Generation: 97	String: To be -r not to bx.	Fitness: 2
# Generation: 98	String: To be -r not to bx.	Fitness: 2
# Generation: 99	String: To be -r not to bx.	Fitness: 2
# Generation: 100	String: To be -r not to bx.	Fitness: 2
# Generation: 101	String: To be -r not to bx.	Fitness: 2
# Generation: 102	String: To be -r not to bx.	Fitness: 2
# Generation: 103	String: To be -r not to bx.	Fitness: 2
# Generation: 104	String: To be -r not to bx.	Fitness: 2
# Generation: 105	String: To be -r not to bx.	Fitness: 2
# Generation: 106	String: To be -r not to bx.	Fitness: 2
# Generation: 107	String: To be -r not to bx.	Fitness: 2
# Generation: 108	String: To be -r not to bx.	Fitness: 2
# Generation: 109	String: To be -r not to bx.	Fitness: 2
# Generation: 110	String: To be -r not to bx.	Fitness: 2
# Generation: 111	String: To be -r not to bx.	Fitness: 2
# Generation: 112	String: To be -r not to bx.	Fitness: 2
# Generation: 113	String: To be -r not to bx.	Fitness: 2
# Generation: 114	String: To be -r not to bx.	Fitness: 2
# Generation: 115	String: To be -r not to bx.	Fitness: 2
# Generation: 116	String: To be -r not to bx.	Fitness: 2
# Generation: 117	String: To be -r not to bx.	Fitness: 2
# Generation: 118	String: To be -r not to bx.	Fitness: 2
# Generation: 119	String: To be -r not to bx.	Fitness: 2
# Generation: 120	String: To be -r not to bx.	Fitness: 2
# Generation: 121	String: To be -r not to bx.	Fitness: 2
# Generation: 122	String: To be -r not to bx.	Fitness: 2
# Generation: 123	String: To be -r not to bx.	Fitness: 2
# Generation: 124	String: To be -r not to bx.	Fitness: 2
# Generation: 125	String: To be -r not to bx.	Fitness: 2
# Generation: 126	String: To be -r not to bx.	Fitness: 2
# Generation: 127	String: To be -r not to bx.	Fitness: 2
# Generation: 128	String: To be -r not to bx.	Fitness: 2
# Generation: 129	String: To be -r not to bx.	Fitness: 2
# Generation: 130	String: To be -r not to bx.	Fitness: 2
# Generation: 131	String: To be -r not to bx.	Fitness: 2
# Generation: 132	String: To be -r not to bx.	Fitness: 2
# Generation: 133	String: To be or not to b .	Fitness: 1
# Generation: 134	String: To be or not to b .	Fitness: 1
# Generation: 135	String: To be or not to b .	Fitness: 1
# Generation: 136	String: To be or not to b .	Fitness: 1
# Generation: 137	String: To be or not to b .	Fitness: 1
# Generation: 138	String: To be or not to b .	Fitness: 1
# Generation: 139	String: To be or not to b .	Fitness: 1
# Generation: 140	String: To be or not to b .	Fitness: 1
# Generation: 141	String: To be or not to b .	Fitness: 1
# Generation: 142	String: To be or not to b .	Fitness: 1
# Generation: 143	String: To be or not to b .	Fitness: 1
# Generation: 144	String: To be or not to b .	Fitness: 1
# Generation: 145	String: To be or not to b .	Fitness: 1
# Generation: 146	String: To be or not to b .	Fitness: 1
# Generation: 147	String: To be or not to b .	Fitness: 1
# Generation: 148	String: To be or not to b .	Fitness: 1
# Generation: 149	String: To be or not to b .	Fitness: 1
# Generation: 150	String: To be or not to b .	Fitness: 1
# Generation: 151	String: To be or not to b .	Fitness: 1
# Generation: 152	String: To be or not to b .	Fitness: 1
# Generation: 153	String: To be or not to b .	Fitness: 1
# Generation: 154	String: To be or not to b .	Fitness: 1
# Generation: 155	String: To be or not to be.	Fitness: 0
